# %% [markdown]
# # Esto es un titulo en markdown
# ## esto es un subtitutulo en markdown
# Esto es un texto para un paragrafo en markdown
#
# *Esto es un texto en cursiva*
# **Esto es un texto en negrita**

# %%
print ("Hola mundo!")
# Out:
# Hola mundo!

# %%
print ("Print es una instruccion que muestra texto por pantalla")
# Out:
# Print es una instruccion que muestra texto por pantalla
