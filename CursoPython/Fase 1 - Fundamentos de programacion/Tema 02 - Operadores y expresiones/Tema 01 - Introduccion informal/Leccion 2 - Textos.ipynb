# %%
"hola mundo"
# Out:
# 'hola mundo'

# %%
'hola mundo'
# Out:
# 'hola mundo'

# %%
'Este texto incluye unas comillas "" '
# Out:
# 'Este texto incluye unas comillas "" '

# %%
'este texto incluye unas comillas '' '
# Out:
# 'este texto incluye unas comillas  '

# %%
"esta 'palabra' se encuentra escrita entre en comillas simples"
# Out:
# "esta 'palabra' se encuentra escrita entre en comillas simples"

# %%
"esta\"palabra\" se encuentra escrita entre comillas  dobles "
# Out:
# 'esta"palabra" se encuentra escrita entre comillas  dobles '

# %%
'esta\'palabra\' se encuentra escrita entre comillas  dobles '
# Out:
# "esta'palabra' se encuentra escrita entre comillas  dobles "

# %%
"una cadena"
"otra cadena"
"otra cadena mas"
# Out:
# 'otra cadena mas'

# %%
print ("una cadena")
print ('otra cadena')
print ('otra cadena mas')
# Out:
# una cadena
# otra cadena
# otra cadena mas

# %%
print ("un texto\tuna tabulacion")
# Out:
# un texto	una tabulacion

# %%
print ("un texto\nuna nueva linea")
# Out:
# un texto
# una nueva linea

# %%
print("c:\nombre\directorio")
# Out:
# c:
# ombre\directorio
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15268\1857430480.py:1: SyntaxWarning: invalid escape sequence '\d'
#   print("c:\nombre\directorio")

# %%
print(r"c:\nombre\directorio")
# Out:
# c:\nombre\directorio

# %%
print ("""una linea
otra linea
ota linea\tuna tabulacion""")
# Out:
# una linea
# otra linea
# ota linea	una tabulacion

# %%
c = "es una cadena \ncon dos lineas"

# %%
c
# Out:
# 'es una cadena \ncon dos lineas'

# %%
print (c)
# Out:
# es una cadena
# con dos lineas

# %%
c+c
# Out:
# 'es una cadena \ncon dos lineases una cadena \ncon dos lineas'

# %%
print (c+c)
# Out:
# es una cadena
# con dos lineases una cadena
# con dos lineas

# %%
s = "una cadena" "compuesta de dos cadenas"
print (s)
# Out:
# una cadenacompuesta de dos cadenas

# %%
c1 = "una cadena"
c2 = "otra cadena"
print (c1 + c2)
# Out:
# una cadenaotra cadena

# %%
print (c1)
# Out:
# una cadena

# %%
diez_espacios = " " * 10
print ( diez_espacios + "un texto a diez espacios")
# Out:
#           un texto a diez espacios
